# %%
from bs4 import BeautifulSoup
import requests
import smtplib
import time
import datetime
import csv
import pandas as pd

# %%
URL='https://www.jumia.co.ke/umidigi-a13-pro-4gb128gb-rom-6.7-hd-5150mah-20mp8mp2mpfront-8mp-starry-black-100992644.html'

# %%
headers={"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36"}
page=requests.get(URL)
soup1=BeautifulSoup(page.content,'lxml')
print(soup1)
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en"><head><meta charset="utf-8"/><title>UMIDIGI A13 Pro (4GB,128GB ROM) 6.7" HD 5150mAh (20MP+8MP+2MP)+FRONT 8MP-Starry Black @ Best Price Online | Jumia Kenya</title><meta content="product" property="og:type"/><meta content="Jumia Kenya" property="og:site_name"/><meta content='A13 Pro (4GB,128GB ROM) 6.7" HD 5150mAh (20MP+8MP+2MP)+FRONT 8MP-Starry Black' property="og:title"/><meta content='Welcome to UMIDIGI Official Store on JUMIA.
#
#
#
# UMIDIGI is a smartphone manufacturing-based company founded in China Shenzhen in 2012, which commits to delivering exquisite mobile electronic devices. That is focused on premium products, differentiating innovation, achieving technological breakthroughs, and delivering global customers an extraordinary mobile experience with meticulous designs and advanced technology. To make premium products accessible to everyone at an affordable price.
#
#
#
# UMIDIGI A13 PRO
#
#
#
#
#
#
# 			Brand
# 			UMIDIGI
#
#
# ...

# %%
soup2 = BeautifulSoup(soup1.prettify(), "lxml")
print(soup2)

title = soup2.find('title').text.strip()
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>
#    UMIDIGI A13 Pro (4GB,128GB ROM) 6.7" HD 5150mAh (20MP+8MP+2MP)+FRONT 8MP-Starry Black @ Best Price Online | Jumia Kenya
#   </title>
# <meta content="product" property="og:type"/>
# <meta content="Jumia Kenya" property="og:site_name"/>
# <meta content='A13 Pro (4GB,128GB ROM) 6.7" HD 5150mAh (20MP+8MP+2MP)+FRONT 8MP-Starry Black' property="og:title"/>
# <meta content='Welcome to UMIDIGI Official Store on JUMIA.
#
#
#
# UMIDIGI is a smartphone manufacturing-based company founded in China Shenzhen in 2012, which commits to delivering exquisite mobile electronic devices. That is focused on premium products, differentiating innovation, achieving technological breakthroughs, and delivering global customers an extraordinary mobile experience with meticulous designs and advanced technology. To make premium products accessible to everyone at an affordable price.
#
#
#
# UMIDIGI A13 PRO
#
#
#
#
#
#
# ...

# %%
title = soup2.find('h1').text.strip()[:15]
print(title)
# Out:
# UMIDIGI A13 Pro

# %%
div_tag = soup2.find_all(class_ ='-b -ltr -tal -fs24')
for price in div_tag:
    umidigi=price.text.strip()[3:]
    print(umidigi)
# Out:
#  14,090

# %%
umidigi.strip()
today=datetime.date.today()
print(today)
# Out:
# 2023-04-13

# %%
headers=['Product','Price','Date']
data=[title,umidigi,today]
with open('jumia.csv','a+',newline='') as file:
    writer=csv.writer(file)
    writer.writerow(data)

# %%
df=pd.read_csv(r'C:\Users\User/jumia.csv')
df
# Out:
#              Product    Price        Date
# 0    UMIDIGI A13 Pro   14,090  2023-04-13
# 1    UMIDIGI A13 Pro   14,090  2023-04-13
# 2    UMIDIGI A13 Pro   14,090  2023-04-13
# 3    UMIDIGI A13 Pro   14,090  2023-04-13
# 4    UMIDIGI A13 Pro   14,090  2023-04-13
# ..               ...      ...         ...
# 271  UMIDIGI A13 Pro   14,090  2023-04-13
# 272  UMIDIGI A13 Pro   14,090  2023-04-13
# 273  UMIDIGI A13 Pro   14,090  2023-04-13
# 274  UMIDIGI A13 Pro   14,090  2023-04-13
# 275  UMIDIGI A13 Pro   14,090  2023-04-13
#
# [276 rows x 3 columns]

# %%
def check_price():
    URL='https://www.jumia.co.ke/umidigi-a13-pro-4gb128gb-rom-6.7-hd-5150mah-20mp8mp2mpfront-8mp-starry-black-100992644.html'
    headers={"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36"}
    page=requests.get(URL)
    soup1=BeautifulSoup(page.content,'lxml')
    soup2 = BeautifulSoup(soup1.prettify(), "lxml")
    title = soup2.find('title').text.strip()
    title = soup2.find('h1').text.strip()[:15]
    today=datetime.date.today()
    div_tag = soup2.find_all(class_ ='-b -ltr -tal -fs24')
    for price in div_tag:
        umidigi=price.text.strip()[3:]
        umidigi.strip()
    headers=['Product','Price','Date']
    data=[title,umidigi,today]
    with open('jumia.csv','a+',newline='') as file:
        writer=csv.writer(file)
        writer.writerow(data)
        df=pd.read_csv(r'C:\Users\User/jumia.csv')
    if umidigi==14090:
        send_mail()

# %%
while True:
    check_price()
    time.sleep(80000)

# %%
df

# %%
print(df)

# %%
df=pd.read_csv(r'C:\Users\User/jumia.csv')
df

# %%
def send_mail():
    server = smtplib.SMTP_SSL('smtp.gmail.com',465)
    server.ehlo()
    #server.starttls()
    server.ehlo()
    server.login('jamesbengi21@gmail.com','xxxx')
    
    subject = "Grab the phone Now!"
    body = "James this is the moment we have been waiting for log in to jumia and secure the phone"
   
    msg = f"Subject: {subject}\n\n{body}"
    
    server.sendmail(
        'jamesbengi21@gmail.com',
        msg
     
    )
